# %% [markdown]
# Name :Abbas sarfaraz

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score

data = {
    'Age': [25, 40, 35, 50, 23],
    'Monthly Spend': [200, 300, 150, 400, 120],
    'Number of Support Calls': [1, 2, 1, 3, 2],
    'Account Type': ['Basic', 'Premium', 'Basic', 'Premium', 'Basic'],
    'Leave': ['No', 'Yes', 'No', 'Yes', 'No']
}
df = pd.DataFrame(data)
df['Account Type'] = pd.get_dummies(df['Account Type'], drop_first=True)
label_encoder = LabelEncoder()
df['Leave'] = label_encoder.fit_transform(df['Leave'])
X = df.drop('Leave', axis=1)
y = df['Leave']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
model = Sequential()

model.add(Dense(10, input_dim=X_scaled.shape[1], activation='relu'))


model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype("int32")
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.5291
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.5247
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.5204
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.5161
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.5119
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.5076
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.5034
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.4989
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.4945
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.4900
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4856
# Epoch 12/100
# ...

# %%
#Report accuracy
accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy on test set: {accuracy:.2f}')
# Out:
# Accuracy on test set: 1.00

# %% [markdown]
# Summary of the Models Performance:
#
# Accuracy: The code provides the accuracy of the model on the test set.
# Potential Improvements: If the performance is not satisfactory, you could increase the model's complexity, adjust the learning rate, or use regularization techniques like dropout.
# Deliverables:
#
# Code:
#  The provided code includes all steps from data preprocessing to model evaluation.
# Summary:
#  The accuracy is reported, and suggestions for improvement are discussed.
